# %% [markdown]
# <a href="https://colab.research.google.com/github/21BCE0420/BCSE331L-EDA/blob/main/21BCE0420.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **AATHIL IBRAHIM**
# ###**21BCE0420**
# #####https://github.com/21BCE0420/BCSE331L-EDA/blob/main/21BCE0420.ipynb
# #CreditCard.csv

# %% [markdown]
# # **MOD 2**
# ## **DATA HANDLING**

# %% [markdown]
# Check for missing values

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/salemprakash/EDA/main/Data/CreditCard.csv")
df.isnull().sum()
# Out:
# rownames       0
# card           0
# reports        0
# age            0
# income         0
# share          0
# expenditure    0
# owner          0
# selfemp        0
# dependents     0
# months         0
# majorcards     0
# active         0
# dtype: int64

# %% [markdown]
# no missing values

# %% [markdown]
# ## **Removing Duplicates**

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# no duplicates

# %% [markdown]
# ## **Data Transformation**

# %%
# Convert 'age' to integer
df['age'] = df['age'].astype(int)
df
# Out:
#       rownames card  reports  age  income     share  expenditure owner  \
# 0            1  yes        0   37  4.5200  0.033270   124.983300   yes
# 1            2  yes        0   33  2.4200  0.005217     9.854167    no
# 2            3  yes        0   33  4.5000  0.004156    15.000000   yes
# 3            4  yes        0   30  2.5400  0.065214   137.869200    no
# 4            5  yes        0   32  9.7867  0.067051   546.503300   yes
# ...        ...  ...      ...  ...     ...       ...          ...   ...
# 1314      1315  yes        0   33  4.5660  0.002146     7.333333   yes
# 1315      1316   no        5   23  3.1920  0.000376     0.000000    no
# 1316      1317  yes        0   40  4.6000  0.026513   101.298300   yes
# 1317      1318  yes        0   32  3.7000  0.008999    26.996670    no
# 1318      1319  yes        0   48  3.7000  0.111619   344.157500   yes
#
#      self_employed  dependents  months  majorcards  active  \
# ...

# %%
# Rename 'selfemp' to 'self_employed'
df.rename(columns={'selfemp': 'self_employed'}, inplace=True)
df
# Out:
#       rownames card  reports  age  income     share  expenditure owner  \
# 0            1  yes        0   37  4.5200  0.033270   124.983300   yes
# 1            2  yes        0   33  2.4200  0.005217     9.854167    no
# 2            3  yes        0   33  4.5000  0.004156    15.000000   yes
# 3            4  yes        0   30  2.5400  0.065214   137.869200    no
# 4            5  yes        0   32  9.7867  0.067051   546.503300   yes
# ...        ...  ...      ...  ...     ...       ...          ...   ...
# 1314      1315  yes        0   33  4.5660  0.002146     7.333333   yes
# 1315      1316   no        5   23  3.1920  0.000376     0.000000    no
# 1316      1317  yes        0   40  4.6000  0.026513   101.298300   yes
# 1317      1318  yes        0   32  3.7000  0.008999    26.996670    no
# 1318      1319  yes        0   48  3.7000  0.111619   344.157500   yes
#
#      self_employed  dependents  months  majorcards  active  \
# ...

# %%
# Create a new column 'balance_to_income_ratio'
df['balance_to_income_ratio'] = df['expenditure'] / df['income']
df
# Out:
#       rownames card  reports  age  income     share  expenditure owner  \
# 0            1  yes        0   37  4.5200  0.033270   124.983300   yes
# 1            2  yes        0   33  2.4200  0.005217     9.854167    no
# 2            3  yes        0   33  4.5000  0.004156    15.000000   yes
# 3            4  yes        0   30  2.5400  0.065214   137.869200    no
# 4            5  yes        0   32  9.7867  0.067051   546.503300   yes
# ...        ...  ...      ...  ...     ...       ...          ...   ...
# 1314      1315  yes        0   33  4.5660  0.002146     7.333333   yes
# 1315      1316   no        5   23  3.1920  0.000376     0.000000    no
# 1316      1317  yes        0   40  4.6000  0.026513   101.298300   yes
# 1317      1318  yes        0   32  3.7000  0.008999    26.996670    no
# 1318      1319  yes        0   48  3.7000  0.111619   344.157500   yes
#
#      self_employed  dependents  months  majorcards  active  \
# ...

# %% [markdown]
# ##  **Value Counts and Unique Values**

# %%
# Value counts for 'card' column
print(df['card'].value_counts())

# Unique values in 'owner' column
print(df['owner'].unique())
# Out:
# card
# yes    1023
# no      296
# Name: count, dtype: int64
# ['yes' 'no']

# %% [markdown]
# ## **Grouping and Aggregations**

# %%
# Average expenditure by card ownership
avg_expenditure_by_card = df.groupby('card')['expenditure'].mean()
print(avg_expenditure_by_card)

# Sum of income by number of dependents
income_by_dependents = df.groupby('dependents')['income'].sum()
print(income_by_dependents)
# Out:
# card
# no       0.000000
# yes    238.602421
# Name: expenditure, dtype: float64
# dependents
# 0    1953.3489
# 1     874.3845
# 2     817.1575
# 3     494.7308
# 4     225.7891
# 5      40.4295
# 6      33.0907
# Name: income, dtype: float64

# %% [markdown]
# ## **Merging DataFrames**

# %%
# Sample additional DataFrame
df_additional = pd.DataFrame({
    'rownames': [1, 2, 3],
    'credit_score': [700, 650, 720]
})
# Merge on 'rownames'
df_merged = pd.merge(df, df_additional, on='rownames', how='left')
df_merged
# Out:
#       rownames card  reports  age  income     share  expenditure owner  \
# 0            1  yes        0   37  4.5200  0.033270   124.983300   yes
# 1            2  yes        0   33  2.4200  0.005217     9.854167    no
# 2            3  yes        0   33  4.5000  0.004156    15.000000   yes
# 3            4  yes        0   30  2.5400  0.065214   137.869200    no
# 4            5  yes        0   32  9.7867  0.067051   546.503300   yes
# ...        ...  ...      ...  ...     ...       ...          ...   ...
# 1314      1315  yes        0   33  4.5660  0.002146     7.333333   yes
# 1315      1316   no        5   23  3.1920  0.000376     0.000000    no
# 1316      1317  yes        0   40  4.6000  0.026513   101.298300   yes
# 1317      1318  yes        0   32  3.7000  0.008999    26.996670    no
# 1318      1319  yes        0   48  3.7000  0.111619   344.157500   yes
#
#      self_employed  dependents  months  majorcards  active  \
# ...

# %% [markdown]
# ## **Pivot Tables and Crosstabulation**

# %%
# Pivot table: average expenditure by card and owner status
pivot_table = df.pivot_table(values='expenditure', index='card', columns='owner', aggfunc='mean')
print(pivot_table)

# Crosstab: frequency of card ownership by self-employment status
crosstab = pd.crosstab(df['card'], df['self_employed'])
print(crosstab)
# Out:
# owner          no         yes
# card
# no       0.000000    0.000000
# yes    225.505399  252.793084
# self_employed   no  yes
# card
# no             268   28
# yes            960   63

# %% [markdown]
# ## **Applying Functions**

# %%
# Define a function to categorize income levels
def categorize_income(income):
    if income < 2.5:
        return 'Low'
    elif 2.5 <= income < 5:
        return 'Medium'
    else:
        return 'High'

# Apply the function to create a new column
df['income_category'] = df['income'].apply(categorize_income)
df
# Out:
#       rownames card  reports  age  income     share  expenditure owner  \
# 0            1  yes        0   37  4.5200  0.033270   124.983300   yes
# 1            2  yes        0   33  2.4200  0.005217     9.854167    no
# 2            3  yes        0   33  4.5000  0.004156    15.000000   yes
# 3            4  yes        0   30  2.5400  0.065214   137.869200    no
# 4            5  yes        0   32  9.7867  0.067051   546.503300   yes
# ...        ...  ...      ...  ...     ...       ...          ...   ...
# 1314      1315  yes        0   33  4.5660  0.002146     7.333333   yes
# 1315      1316   no        5   23  3.1920  0.000376     0.000000    no
# 1316      1317  yes        0   40  4.6000  0.026513   101.298300   yes
# 1317      1318  yes        0   32  3.7000  0.008999    26.996670    no
# 1318      1319  yes        0   48  3.7000  0.111619   344.157500   yes
#
#      self_employed  dependents  months  majorcards  active  \
# ...

# %% [markdown]
# #**MOD 3**
# ##**Outlier detection and filtering**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.title("21BCE0420 - Box Plot of Rownames, Reports, and Age")
sns.boxplot(data=df[['rownames', 'reports', 'age']])
plt.show()

# %%
plt.figure()
plt.title("21BCE0420 - Box Plot of Income, Share, and Expenditure")
sns.boxplot(data=df[['income', 'share', 'expenditure']])
plt.show()

# %%
plt.figure()
plt.title("21BCE0420 - Box Plot of Dependents, Months, Major Cards, and Active")
sns.boxplot(data=df[['dependents', 'months', 'majorcards', 'active']])
plt.show()

# %% [markdown]
# **MODULE 3**

# %% [markdown]
# ## **Univariate analysis**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
print(df.head(3))
print(df.tail(3))
# Out:
#    rownames card  reports  age  income     share  expenditure owner  \
# 0         1  yes        0   37    4.52  0.033270   124.983300   yes
# 1         2  yes        0   33    2.42  0.005217     9.854167    no
# 2         3  yes        0   33    4.50  0.004156    15.000000   yes
#
#   self_employed  dependents  months  majorcards  active  \
# 0            no           3      54           1      12
# 1            no           3      34           1      13
# 2            no           4      58           1       5
#
#    balance_to_income_ratio income_category
# 0                27.651173          Medium
# 1                 4.071970             Low
# 2                 3.333333          Medium
#       rownames card  reports  age  income     share  expenditure owner  \
# 1316      1317  yes        0   40     4.6  0.026513    101.29830   yes
# 1317      1318  yes        0   32     3.7  0.008999     26.99667    no
# 1318      1319  yes        0   48     3.7  0.111619    344.15750   yes
#
# ...

# %%
df.dtypes
# Out:
# rownames                     int64
# card                        object
# reports                      int64
# age                          int64
# income                     float64
# share                      float64
# expenditure                float64
# owner                       object
# self_employed               object
# dependents                   int64
# months                       int64
# majorcards                   int64
# active                       int64
# balance_to_income_ratio    float64
# income_category             object
# dtype: object

# %%
print(df.describe())
pd.isna(df).any()
# Out:
#           rownames      reports          age       income        share  \
# count  1319.000000  1319.000000  1319.000000  1319.000000  1319.000000
# mean    660.000000     0.456406    32.763457     3.365376     0.068732
# std     380.906813     1.345267    10.145759     1.693902     0.094656
# min       1.000000     0.000000     0.000000     0.210000     0.000109
# 25%     330.500000     0.000000    25.000000     2.243750     0.002316
# 50%     660.000000     0.000000    31.000000     2.900000     0.038827
# 75%     989.500000     0.000000    39.000000     4.000000     0.093617
# max    1319.000000    14.000000    83.000000    13.500000     0.906320
#
#        expenditure   dependents       months   majorcards       active  \
# count  1319.000000  1319.000000  1319.000000  1319.000000  1319.000000
# mean    185.057071     0.993935    55.267627     0.817286     6.996967
# std     272.218917     1.247745    66.271746     0.386579     6.305812
# ...

# %% [markdown]
# ## **Data Cleaning**

# %%
# Find out the number of values which are not numeric
df['owner'].str.isnumeric().value_counts()
# Out:
# owner
# False    1319
# Name: count, dtype: int64

# %%
# List out the values which are not numeric
df['owner'].loc[df['owner'].str.isnumeric() == False]
# Out:
# 0       yes
# 1        no
# 2       yes
# 3        no
# 4       yes
#        ...
# 1314    yes
# 1315     no
# 1316    yes
# 1317     no
# 1318    yes
# Name: owner, Length: 1319, dtype: object

# %%
#Compute the measure of central tendency of the height column.
#Descriptive Statistics
#Calculate mean, median and mode of dat set height
mean = df["age"].mean()
median =df["age"].median()
mode = df["age"].mode()
print(mean , median, mode)
# Out:
# 32.76345716451858 31.0 0    25
# Name: age, dtype: int64

# %%
df['age'].value_counts().nlargest(30).plot(kind='bar', figsize=(10,6))
plt.title("21BCE0420 - Top 30 Most Frequent Values in Age")
plt.ylabel("Count")
plt.xlabel("Age")
plt.xticks(rotation=45)
plt.show()

# %%
# Distribution plot for 'age'
g = sns.FacetGrid(df)
g.map(sns.histplot, "age", kde=True)
g.add_legend()
plt.title("21BCE0420 - Distribution plot for Age")
plt.show()

# %%
# Boxplot for 'age'
plt.figure()
sns.boxplot(x="age", data=df)
plt.title("21BCE0420 - Boxplot for age")
plt.show()

# %% [markdown]
# ##   **Bivariate Analysis**

# %%
# Scatter plot for 'income' vs 'expenditure'
plt.figure(figsize=(8, 6))
plt.scatter(df["income"], df["expenditure"], alpha=0.5)
plt.title("21BCE0420 - Scatter Plot for Income vs Expenditure")
plt.xlabel("Income")
plt.ylabel("Expenditure")
plt.show()

# %%
# Relationship between two features
np.corrcoef(df["income"], df["expenditure"])
# Out:
# array([[1.        , 0.28110402],
#        [0.28110402, 1.        ]])

# %% [markdown]
# ## **Multivariate Analysis**

# %%
# Selecting three numerical columns from the dataset
numerical_columns = df.select_dtypes(include=['number']).columns
selected_columns = numerical_columns[:3]  # Picking the first three numerical columns

# Set the title
plt.figure(figsize=(10, 6))
plt.suptitle("21BCE0420 - Pair Plot with Regression")

# Plot the pair plot with regression
sns.pairplot(df, vars=selected_columns, kind="reg")
plt.show()

# %%
# Selecting three numerical columns for the pair plot
selected_columns = ['income', 'expenditure', 'share']

# Set the title
plt.figure(figsize=(10, 6))
plt.suptitle("21BCE0420 - Pair Plot of Income, Expenditure, and Share by Ownership", fontsize=14, fontweight='bold')

# Setting style and creating pair plot
sns.set(style="ticks", color_codes=True)
sns.pairplot(df, height=2, vars=selected_columns, hue="owner")
plt.show()

# %%
import pandas as pd
from scipy import stats

# Selecting two numerical columns for correlation
col1 = "income"
col2 = "expenditure"

# Compute Pearson correlation coefficient
corr = stats.pearsonr(df[col1], df[col2])

# Display results
corr_results = {
    "p-value": corr[1],
    "correlation": corr[0]
}
corr_results
# Out:
# {'p-value': 2.230294885938356e-25, 'correlation': 0.28110401821777764}

# %%
correlation = df.corr(method='pearson', numeric_only=True)
correlation
# Out:
#              rownames   reports       age    income     share  expenditure  \
# rownames     1.000000  0.023081  0.071369 -0.026195  0.066335     0.034549
# reports      0.023081  1.000000  0.044089  0.011023 -0.159011    -0.136538
# age          0.071369  0.044089  1.000000  0.324653 -0.115697     0.014948
# income      -0.026195  0.011023  0.324653  1.000000 -0.054429     0.281104
# share        0.066335 -0.159011 -0.115697 -0.054429  1.000000     0.838779
# expenditure  0.034549 -0.136538  0.014948  0.281104  0.838779     1.000000
# dependents   0.052303  0.019731  0.212146  0.317601 -0.082618     0.052664
# months       0.080723  0.048968  0.436426  0.130346 -0.055348    -0.029007
# majorcards  -0.002221 -0.007304  0.009777  0.107138  0.051470     0.077514
# active       0.004624  0.207755  0.181070  0.180540 -0.023474     0.054724
#
#              dependents    months  majorcards    active
# rownames       0.052303  0.080723   -0.002221  0.004624
# ...

# %%
#Visualize this correlation analysis using a heatmap.
#A heatmap is the best technique to make this look beautiful and easier to interpret:
sns.heatmap(correlation,xticklabels=correlation.columns,
            yticklabels=correlation.columns)
plt.title("21BCE0420 - CORRELATION HEATMAP", fontsize=14, fontweight='bold')
# Out:
# Text(0.5, 1.0, '21BCE0420 - CORRELATION HEATMAP')

# %% [markdown]
# #**MOD 4**
# ## **1D Analysis**

# %%
#Load the necessary package for 1D analysis
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/salemprakash/EDA/main/Data/CreditCard.csv")
df.head()
# Out:
#    rownames card  reports       age  income     share  expenditure owner  \
# 0         1  yes        0  37.66667  4.5200  0.033270   124.983300   yes
# 1         2  yes        0  33.25000  2.4200  0.005217     9.854167    no
# 2         3  yes        0  33.66667  4.5000  0.004156    15.000000   yes
# 3         4  yes        0  30.50000  2.5400  0.065214   137.869200    no
# 4         5  yes        0  32.16667  9.7867  0.067051   546.503300   yes
#
#   selfemp  dependents  months  majorcards  active
# 0      no           3      54           1      12
# 1      no           3      34           1      13
# 2      no           4      58           1       5
# 3      no           0      25           1       7
# 4      no           2      64           1       5

# %%
# Select a numerical column for analysis
num_col = "income"

# %%
# Calculate summary statistics
mean_val = df[num_col].mean()
median_val = df[num_col].median()
mode_val = df[num_col].mode().values[0]
skewness_val = df[num_col].skew()
kurtosis_val = df[num_col].kurt()

# %%
# Print summary statistics
print("Summary Statistics:")
print(f"Mean: {mean_val:.2f}")
print(f"Median: {median_val:.2f}")
print(f"Mode: {mode_val:.2f}")
print(f"Skewness: {skewness_val:.2f}")
print(f"Kurtosis: {kurtosis_val:.2f}")
# Out:
# Summary Statistics:
# Mean: 3.37
# Median: 2.90
# Mode: 3.00
# Skewness: 1.93
# Kurtosis: 4.93

# %%
# Create a skewness plot
plt.figure(figsize=(10, 6))
sns.distplot(df[num_col], kde=False, rug=True)
plt.title("Skewness Plot-21BCE0420")
plt.xlabel(num_col)
plt.ylabel("Density")
plt.show()
# Out:
# <ipython-input-8-6816b6113631>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[num_col], kde=False, rug=True)

# %%
# Create a kurtosis plot
plt.figure(figsize=(10, 6))
sns.kdeplot(df[num_col], shade=True)
plt.title("Kurtosis Plot-21BCE0420")
plt.xlabel(num_col)
plt.ylabel("Density")
plt.show()
# Out:
# <ipython-input-9-acdbc8f7d586>:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[num_col], shade=True)

# %%
# Create a histogram with frequency
plt.figure(figsize=(10, 6))
df[num_col].plot.hist(bins=20, edgecolor="black")
plt.title("Frequency Distribution-21BCE0420")
plt.xlabel(num_col)
plt.ylabel("Frequency")
plt.show()

# %%
# Create a box plot
plt.figure(figsize=(10, 6))
sns.boxplot(df[num_col])
plt.title("Box Plot-21BCE0420")
plt.xlabel(num_col)
plt.show()

# %%
# Create a bar plot
plt.figure(figsize=(10, 6))
df[num_col].value_counts().plot(kind="bar")
plt.title("Bar Plot-21BCE0420")
plt.xlabel(num_col)
plt.ylabel("Count")
plt.show()

# %%
# Create a cumulative frequency plot
plt.figure(figsize=(10, 6))
df[num_col].plot(kind="hist", cumulative=True, bins=20, edgecolor="black")
plt.title("Cumulative Frequency Distribution-21BCE0420")
plt.xlabel(num_col)
plt.ylabel("Cumulative Frequency")
plt.show()

# %% [markdown]
# ##**3D ANALYSIS**

# %%
pip install python-ternary

# %%
import pandas as pd
import ternary
import matplotlib.pyplot as plt

# Take first 5 rows for symbol-based ternary plotting
subset = df[['income', 'share', 'expenditure']].head(5)
symbols = ['o', 's', 'd', '^', 'v']  # Circle, Square, Diamond, Triangle Up, Triangle Down

# Normalize the data (row-wise sum to 1)
normalized = subset.div(subset.sum(axis=1), axis=0)

# Create tuples: (income, share, expenditure, symbol)
ternary_data = list(normalized.itertuples(index=False, name=None))
annotated_data = [(income, share, expenditure, symbols[i]) for i, (income, share, expenditure) in enumerate(ternary_data)]

# Plot
figure, tax = ternary.figure(scale=1)
tax.boundary(linewidth=2.0)
tax.gridlines(color="gray", multiple=0.1)

# Plot each point with its own symbol
for income, share, expenditure, symbol in annotated_data:
    tax.scatter([(income, share, expenditure)], marker=symbol, color='blue', s=100,
                label=f"({income*100:.1f},{share*100:.1f},{expenditure*100:.1f})")

# Axis labels
tax.left_corner_label("Income", fontsize=12)
tax.right_corner_label("Share", fontsize=12)
tax.top_corner_label("Expenditure", fontsize=12)

# Ticks, legend, title
tax.ticks(axis='lbr', multiple=0.1, linewidth=1, fontsize=10)
tax.legend()
tax.set_title("Ternary Plot with Symbols: Credit Card Data-21BCE0420", fontsize=14)
tax.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/ternary/plotting.py:148: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(xs, ys, vmin=vmin, vmax=vmax, **kwargs)

# %% [markdown]
# #**MOD 5**
# ##**K-Means Clustering**

# %%
#Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Importing the dataset
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/salemprakash/EDA/main/Data/CreditCard.csv")
X = df[['income', 'expenditure']].values
# Out:
# array([[37.66667,  4.52   ],
#        [33.25   ,  2.42   ],
#        [33.66667,  4.5    ],
#        ...,
#        [40.58333,  4.6    ],
#        [32.83333,  3.7    ],
#        [48.25   ,  3.7    ]])

# %%
#Using the elbow method to find the optimal number of clusters
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method-21BCE0420')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
#Training the K-Means model on the dataset
kmeans = KMeans(n_clusters=5, random_state=42)
y_kmeans = kmeans.fit_predict(X)

# %%
#Visualising the clusters
plt.figure(figsize=(10, 6))
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s=100, c='red', label='Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s=100, c='blue', label='Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s=100, c='green', label='Cluster 3')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s=100, c='cyan', label='Cluster 4')
plt.scatter(X[y_kmeans == 4, 0], X[y_kmeans == 4, 1], s=100, c='magenta', label='Cluster 5')

# Plot centroids
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1],
            s=300, c='yellow', marker='*', label='Centroids')

plt.title('Clusters of Credit Card Customers-21BCE0420')
plt.xlabel('Income (in $k)')
plt.ylabel('Monthly Expenditure (in $)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ##**Hierarchical Clustering**

# %%
#Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
plt.figure(figsize=(8, 5))
plt.title("Annual Income Distribution-21BCE0420", fontsize=16)
plt.xlabel("Annual Income ($)", fontsize=14)
plt.ylabel("Number of Customers")
plt.grid(True)
plt.hist(df['income'], color='orange', edgecolor='k')
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.title("Expenditure Distribution-21BCE0420", fontsize=16)
plt.xlabel("Expenditure ($)", fontsize=14)
plt.ylabel("Number of Customers")
plt.grid(True)
plt.hist(df['expenditure'], color='green', edgecolor='k')
plt.show()

# %%
#Dendograms

import scipy.cluster.hierarchy as sch
import matplotlib.pyplot as plt

# Selecting 'age' and 'income' for clustering
X = df[['age', 'income']].values

# Plotting the dendrogram
plt.figure(figsize=(15,6))
plt.title('Dendrogram (Age vs Income)-21BCE0420')
plt.xlabel('Customers')
plt.ylabel('Euclidean distances')
dendrogram = sch.dendrogram(sch.linkage(X, method='ward'))
plt.show()

# %% [markdown]
# ##**Optimal number of clusters**

# %%
# Selecting the features (age and income) from my dataset
X = df[['age', 'income']].values

# Plotting the dendrogram
plt.figure(figsize=(15, 6))
plt.title('Dendrogram (Age vs Income)-21BCE0420')
plt.xlabel('Customers')
plt.ylabel('Euclidean distances')

# Horizontal line for deciding number of clusters
plt.hlines(y=190, xmin=0, xmax=1000000, lw=3, linestyles='--', color='blue')
plt.text(x=900, y=220, s='Horizontal line crossing 5 vertical lines', fontsize=14)

# Dendrogram plot
dendrogram = sch.dendrogram(sch.linkage(X, method='ward'))
plt.show()

# %% [markdown]
# #**MOD 6**
# ##**Principal component analysis**

# %%
# Install and load necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
#Load Dataset
df = pd.read_csv("https://raw.githubusercontent.com/salemprakash/EDA/main/Data/CreditCard.csv")

# %%
#Select Only Numeric Columns
numeric_data = df.select_dtypes(include=['float64', 'int64'])
numeric_data.head()
# Out:
#    rownames  reports       age  income     share  expenditure  dependents  \
# 0         1        0  37.66667  4.5200  0.033270   124.983300           3
# 1         2        0  33.25000  2.4200  0.005217     9.854167           3
# 2         3        0  33.66667  4.5000  0.004156    15.000000           4
# 3         4        0  30.50000  2.5400  0.065214   137.869200           0
# 4         5        0  32.16667  9.7867  0.067051   546.503300           2
#
#    months  majorcards  active
# 0      54           1      12
# 1      34           1      13
# 2      58           1       5
# 3      25           1       7
# 4      64           1       5

# %%
#Standardize the Data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(numeric_data)

# %%
#Perform PCA
pca = PCA()
pca_result = pca.fit(scaled_data)

# %%
# Explained Variance (Eigenvalues)
explained_variance = pca.explained_variance_ratio_
cumulative_variance = explained_variance.cumsum()

# Scree Plot
plt.figure(figsize=(8,5))
plt.plot(range(1, len(explained_variance)+1), explained_variance, 'o-', label='Individual Explained Variance')
plt.plot(range(1, len(explained_variance)+1), cumulative_variance, 's--', label='Cumulative Explained Variance')
plt.title('Scree Plot-21BCE0420')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Choose Number of Components (e.g., 2) and Transform Data
n_comp = 2
pca = PCA(n_components=n_comp)
pca_components = pca.fit_transform(scaled_data)

# Add PCA results to dataframe
pca_df = pd.DataFrame(data=pca_components, columns=[f'PC{i+1}' for i in range(n_comp)])
pca_df.head()
# Out:
#         PC1       PC2
# 0 -0.202217  1.311906
# 1 -0.864689  0.424530
# 2 -0.668069  1.051446
# 3 -0.183254 -1.019747
# 4  1.596620  1.940897

# %%
#Plot PCA Components
plt.figure(figsize=(8,6))
sns.scatterplot(x='PC1', y='PC2', data=pca_df)
plt.title('PCA - 2D Projection-21BCE0420')
plt.xlabel(f"PC1 ({explained_variance[0]*100:.2f}%)")
plt.ylabel(f"PC2 ({explained_variance[1]*100:.2f}%)")
plt.grid(True)
plt.show()

# %%
#PCA Loadings (Component Loadings)
loadings = pd.DataFrame(pca.components_.T, columns=[f'PC{i+1}' for i in range(n_comp)],
                        index=numeric_data.columns)
print(loadings)
# Out:
#                   PC1       PC2
# rownames     0.055741  0.083486
# reports     -0.209956  0.152172
# age         -0.033276  0.543870
# income       0.171260  0.480382
# share        0.656866 -0.123964
# expenditure  0.687012  0.059840
# dependents   0.030129  0.374811
# months      -0.060050  0.399177
# majorcards   0.118911  0.089032
# active       0.016199  0.341486

# %% [markdown]
# #**MOD 7**
# ##**Constructing a linear regression model**

# %%
# Importing the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load your dataset
df = pd.read_csv("https://raw.githubusercontent.com/salemprakash/EDA/main/Data/CreditCard.csv")

# Set seaborn style and plot parameters
sns.set(style="ticks", color_codes=True)
plt.rcParams['figure.figsize'] = (8, 5)
plt.rcParams['figure.dpi'] = 150

# Select a few numerical columns to visualize (pick any 4–5 for clarity)
selected_columns = ['age', 'income', 'expenditure', 'share']

# Plot pairwise relationships
sns.pairplot(df[selected_columns])
plt.suptitle("Pairwise Plot of Selected Features-21BCE0420", y=1.02)
plt.show()

# %%
# Print the column names
print("Column names in the dataset:")
print(df.keys())
# Out:
# Column names in the dataset:
# Index(['rownames', 'card', 'reports', 'age', 'income', 'share', 'expenditure',
#        'owner', 'selfemp', 'dependents', 'months', 'majorcards', 'active'],
#       dtype='object')

# %%
#Now that our data is loaded, let's get our DataFrame ready quickly and work ahead:
df.head()
# print the columns present in the dataset
print(df.columns)
# print the top 5 rows in the dataset
print(df.head())
# Out:
# Index(['rownames', 'card', 'reports', 'age', 'income', 'share', 'expenditure',
#        'owner', 'selfemp', 'dependents', 'months', 'majorcards', 'active'],
#       dtype='object')
#    rownames card  reports       age  income     share  expenditure owner  \
# 0         1  yes        0  37.66667  4.5200  0.033270   124.983300   yes
# 1         2  yes        0  33.25000  2.4200  0.005217     9.854167    no
# 2         3  yes        0  33.66667  4.5000  0.004156    15.000000   yes
# 3         4  yes        0  30.50000  2.5400  0.065214   137.869200    no
# 4         5  yes        0  32.16667  9.7867  0.067051   546.503300   yes
#
#   selfemp  dependents  months  majorcards  active
# 0      no           3      54           1      12
# 1      no           3      34           1      13
# 2      no           4      58           1       5
# 3      no           0      25           1       7
# 4      no           2      64           1       5

# %%
#In the new overall dataframe, let's check if we have any missing values:
df.isna().sum()
# Out:
# rownames       0
# card           0
# reports        0
# age            0
# income         0
# share          0
# expenditure    0
# owner          0
# selfemp        0
# dependents     0
# months         0
# majorcards     0
# active         0
# dtype: int64

# %%
# Select only numeric columns
numeric_df = df.select_dtypes(include='number')

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(numeric_df.corr(), square=True, cmap='RdYlGn', annot=True, fmt=".2f")
plt.title("Correlation Heatmap of Numeric Features-21BCE0420")
plt.show()

# %%
# Let's visualize the relationship between 'income' and 'expenditure'
sns.lmplot(x='income', y='expenditure', data=df)
plt.title("Income vs Expenditure (Linear Fit)-21BCE0420")
plt.xlabel("Income")
plt.ylabel("Expenditure")
plt.show()

# %%
#Scikit-learn needs to create features and target variables in arrays, so be careful when assigning columns to X and y:
X = df[['income']]       # Feature
y = df[['expenditure']]  # Target

# %%
# Splitting the dataset into train and test sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 10)

# %%
#Now the final step is training the linear regression model. From the extremely powerful sklearn library, we import the LinearRegression() function to fit
#our training dataset to the model. When we run LinearRegression().fit(), the function automatically calculates the OLS, which we discussed earlier, and
#generates an appropriate line function:
#Training a Linear Regression Model
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
# Fitting the training data to our model
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#Model evaluation
#R^2 can be determined using our test dataset in the LinearRegression.score() method:
#check prediction score/accuracy
regressor.score(X_test, y_test)
# Out:
# 0.08125429901141379

# %%
#Before that, let's predict the y values with our model and evaluate it more. And a target variables DataFrame is also built:
# predict the y values
y_pred=regressor.predict(X_test)
# a data frame with actual and predicted values of y
evaluate = pd.DataFrame({'Actual': y_test.values.flatten(),
'Predicted': y_pred.flatten()})
evaluate.head(10)
# Out:
#        Actual   Predicted
# 0  1898.03300  253.402876
# 1    20.33333  137.197819
# 2     0.00000  195.300347
# 3     0.00000  128.258968
# 4     0.00000  156.192876
# 5     0.00000  115.275288
# 6     0.00000  172.953221
# 7     0.00000  160.742751
# 8    46.29167  107.252669
# 9   436.25920  289.158278

# %%
#The preceding screenshot shows the difference between the actual values and the predicted values. We can see them if we plot them:
evaluate.head(10).plot(kind = 'bar')
# Out:
# <Axes: >

# %%
#Computing accuracy
# Scoring the model
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
# R2 Score
print(f"R2 score: {r2_score(y_test, y_pred)}")
# Mean Absolute Error (MAE)
print(f"MAE score: {mean_absolute_error(y_test, y_pred)}")
# Mean Squared Error (MSE)
print(f"MSE score: {mean_squared_error(y_test, y_pred)}")
# Out:
# R2 score: 0.08125429901141379
# MAE score: 167.19886803359907
# MSE score: 62953.9294289066
